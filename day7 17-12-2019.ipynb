# %% [markdown]
# - topic
#       - tuple
#       - dictionary

# %%
empty = list()
empty1=[]

# %%
t=(1,2)
print(t)
# Out:
# (1, 2)

# %%
print(t[0])
# Out:
# 1

# %%
t.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d0908ae6cae4> in <module>
# ----> 1 t.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-03ac23426653> in <module>
# ----> 1 t[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(1)
# Out:
# 1

# %%
t1=(1,2,3,4,1,1)
print(t1.count(1))
print(t1.count(5))
print(sum(t1),max(t1),min(t1))
# Out:
# 3
# 0
# 12 4 1

# %%
t1.count(5)
# Out:
# 0

# %%
t2=(34,'python',True,89.5)
print(t2)
print(t2[0])
print(t2[2:])
print(t2[1][2])
# Out:
# (34, 'python', True, 89.5)
# 34
# (True, 89.5)
# t

# %%
t3=(3,4,(34,67))
print(t3[2])
print(t3[2][1])
# Out:
# (34, 67)
# 67

# %% [markdown]
# - create a llist .where each sublist consists 3 subject marks of students

# %%
student_marks = [[23,56,89,],[45,56,76],[99,65,34]]
print(student_marks)
# Out:
# [[23, 56, 89], [45, 56, 76], [99, 65, 34]]

# %%
a=[6,8,9]
a.append(sum(a))

# %%
for i in a:
    print(i+1)
    print(i)
# Out:
# 7
# 6
# 9
# 8
# 10
# 9
# 24
# 23

# %%
aplus=[]
for i in a:
    aplus.append(i+1)
    print(aplus)
# Out:
# [7]
# [7, 9]
# [7, 9, 10]
# [7, 9, 10, 24]

# %%
print(a)
# Out:
# [6, 8, 9, 23]

# %%
list(range(len(a)))
# Out:
# [0, 1, 2, 3]

# %%
for i in range(len(a)):
    a[i]=a[i]+1

# %%
print(a)
# Out:
# [7, 9, 10, 24]

# %%
#to access elements
for i in a:
    print(i,end=' ')
    print()
    #to acccess the elements by using index
    for i in range(len(a)):
        print(a[i],end=' ')
# Out:
# 7
# 7 9 10 24 9
# 7 9 10 24 10
# 7 9 10 24 24
# 7 9 10 24

# %% [markdown]
# - dictionary

# %%
d = {'maths':56,'english':67,'physics':45}
d['maths']
# Out:
# 56

# %%
d['physics']=77
d
# Out:
# {'maths': 56, 'english': 67, 'physics': 77}

# %%
d['python']= 78
d
# Out:
# {'maths': 56, 'english': 67, 'physics': 77, 'python': 78}

# %%
for i in d:
    print(i,end=' ')
# Out:
# maths english physics python

# %%
#accessing thevalues using for loop
for i in d:
    print(d[i],end=' ')
# Out:
# 56 67 77 78

# %%
sum(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-3b8b3f92adcf> in <module>
# ----> 1 sum(d)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
s=0
for i in d:
    s+=d[i]
print(s)
# Out:
# 278

# %%
sum(d.values())
# Out:
# 278

# %%
for key,value in d.items():
    print(key,':',value)
# Out:
# maths : 56
# english : 67
# physics : 77
# python : 78

# %%
d.update({'total':sum(d.values())})
print(d)
# Out:
# {'maths': 56, 'english': 67, 'physics': 77, 'python': 78, 'total': 278}

# %%
d.pop('total')
print(d)
# Out:
# {'maths': 56, 'english': 67, 'physics': 77, 'python': 78}

# %% [markdown]
# ## create a dictionary with  3students data
#      - key  - student name
#      - value - list if 3 subjects marks of the students

# %%
std_marks = {'ram':[77,45,34],'sandy':[56,78,94],'rose':[67,89,92]}
std_marks
# Out:
# {'ram': [77, 45, 34], 'sandy': [56, 78, 94], 'rose': [67, 89, 92]}

# %% [markdown]
# Add totalmarks as the last elemts in the list for each student
#  - example o/p
# - {'ram':[77,45,34,156]}

# %%
std_marks['ram']
# Out:
# [77, 45, 34]

# %%
for k,v in std_marks.items():
    std_marks[k].append(sum(v))
std_marks
# Out:
# {'ram': [77, 45, 34, 156],
#  'sandy': [56, 78, 94, 228],
#  'rose': [67, 89, 92, 248]}
