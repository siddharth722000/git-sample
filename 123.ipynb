# %% [markdown]
# ## inserting an image using markdown
#
# ![image](https://i0.wp.com/crickettimes.com/wp-content/uploads/2019/11/csk-ms-dhoni.jpg?fit=700%2C365&ssl=1)

# %% [markdown]
# ## inserting  a site using markdown
# [site](https://www.google.com/search?q=dhoni&oq=dhoni&aqs=chrome.0.69i59j0l7.37732j0j9&sourceid=chrome&ie=UTF-8)

# %% [markdown]
# ## fundamental data types

# %% [markdown]
# - int
# - float
# - complex
# - boolen
# - string

# %%
x=10
print(type(x))
print(x)
# Out:
# <class 'int'>
# 10

# %%
x=3+4j
y=10.35
z=10
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'float'>
# <class 'int'>

# %%
c1=3+5j
c2=4+8j
print(c1+c2)
print(c1*c2)
print(c1-c2)
# Out:
# (7+13j)
# (-28+44j)
# (-1-3j)

# %%
a=10 #boolean
b=5
a>b
# Out:
# True

# %%
s1='abc'
s2='xyz'
s1+s2
print(s1+s2)
# Out:
# abcxyz

# %%
s1="100"
print(type(s1))
# Out:
# <class 'str'>

# %% [markdown]
# ## to check the number is perfectly multiple of 3 and 5

# %%
n=int(input("enter the number:"))
if n%3==0 and n%5==0:
        print("yes")
else:
        
        print("no")
# Out:
# enter the number:15
# yes

# %%
#to chcek the given number positive ,negative or zero
n=int(input("enter the number"))
if n==0:
    print("zero")
elif n>0:
    print("positive")
elif n<0:
    print("negative")
# Out:
# enter the number45
# positive

# %%
#to check the given year is leap year or not?
